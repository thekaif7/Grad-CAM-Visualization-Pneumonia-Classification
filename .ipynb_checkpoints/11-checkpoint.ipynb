# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import display
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
# For test datagenerator, we only normalize the data.
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Creating datagenerator for training, validation and test dataset.

train_generator = test_datagen.flow_from_directory(
        'data/chest_xray/train',
        target_size=(256, 256),
        batch_size=32,
        class_mode='sparse')

validation_generator = test_datagen.flow_from_directory(
        'data/chest_xray/val',
        target_size=(256, 256),
        batch_size=32,
        class_mode='sparse')
print(train_generator.class_indices)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %%
def res_block(X, filter, stage):
    

    # Convolutional_block
    X_copy = X

    f1 , f2, f3 = filter

    # Main Path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)


    # Short path
    X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
    X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

    # ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)

    # Identity Block 1
    X_copy = X


    # Main Path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

    # ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)

    # Identity Block 2
    X_copy = X


    # Main Path
    X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
    X = Activation('relu')(X) 

    X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

    # ADD
    X = Add()([X,X_copy])
    X = Activation('relu')(X)

    return X

# %%
input_shape = (256,256,3)

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3,3))(X_input)

# 1 - stage
X = Conv2D(64, (7,7), strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3,3), strides= (2,2))(X)

# 2- stage
X = res_block(X, filter= [64,64,256], stage= 2)

# 3- stage
X = res_block(X, filter= [128,128,512], stage= 3)

# 4- stage
X = res_block(X, filter= [256,256,1024], stage= 4)

# 5- stage
X = res_block(X, filter= [512,512,2048], stage= 5)

# Average Pooling
X = AveragePooling2D((2,2), name = 'Averagea_Pooling')(X)

# Final layer
X = Flatten()(X)
X = Dropout(0.4)(X)
X = Dense(2, activation = 'softmax', name = 'Dense_final', kernel_initializer= glorot_uniform(seed=0))(X)



model = Model( inputs= X_input, outputs = X, name = 'Resnet18')

model.summary()
# Out:
# Model: "Resnet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 64) 9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 128, 128, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 63, 63, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# res_2_conv_a (Conv2D)           (None, 63, 63, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_a (BatchNormalization (None, 63, 63, 64)   256         res_2_conv_a[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 63, 63, 64)   0           bn_2_conv_a[0][0]
# __________________________________________________________________________________________________
# res_2_conv_b (Conv2D)           (None, 63, 63, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_b (BatchNormalization (None, 63, 63, 64)   256         res_2_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 63, 63, 64)   0           bn_2_conv_b[0][0]
# __________________________________________________________________________________________________
# res_2_conv_c (Conv2D)           (None, 63, 63, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# res_2_conv_copy (Conv2D)        (None, 63, 63, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_c (BatchNormalization (None, 63, 63, 256)  1024        res_2_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_copy (BatchNormalizat (None, 63, 63, 256)  1024        res_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 63, 63, 256)  0           bn_2_conv_c[0][0]
#                                                                  bn_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 63, 63, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_a (Conv2D)     (None, 63, 63, 64)   16448       activation_3[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_a (BatchNormali (None, 63, 63, 64)   256         res_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 63, 63, 64)   0           bn_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_b (Conv2D)     (None, 63, 63, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_b (BatchNormali (None, 63, 63, 64)   256         res_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 63, 63, 64)   0           bn_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_c (Conv2D)     (None, 63, 63, 256)  16640       activation_5[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_c (BatchNormali (None, 63, 63, 256)  1024        res_2_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 63, 63, 256)  0           bn_2_identity_1_c[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 63, 63, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_a (Conv2D)     (None, 63, 63, 64)   16448       activation_6[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_a (BatchNormali (None, 63, 63, 64)   256         res_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 63, 63, 64)   0           bn_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_b (Conv2D)     (None, 63, 63, 64)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_b (BatchNormali (None, 63, 63, 64)   256         res_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 63, 63, 64)   0           bn_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_c (Conv2D)     (None, 63, 63, 256)  16640       activation_8[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_c (BatchNormali (None, 63, 63, 256)  1024        res_2_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 63, 63, 256)  0           bn_2_identity_2_c[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 63, 63, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res_3_conv_a (Conv2D)           (None, 63, 63, 128)  32896       activation_9[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_a (BatchNormalization (None, 63, 63, 128)  512         res_3_conv_a[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 63, 63, 128)  0           bn_3_conv_a[0][0]
# __________________________________________________________________________________________________
# res_3_conv_b (Conv2D)           (None, 63, 63, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_b (BatchNormalization (None, 63, 63, 128)  512         res_3_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 63, 63, 128)  0           bn_3_conv_b[0][0]
# __________________________________________________________________________________________________
# res_3_conv_c (Conv2D)           (None, 63, 63, 512)  66048       activation_11[0][0]
# __________________________________________________________________________________________________
# res_3_conv_copy (Conv2D)        (None, 63, 63, 512)  131584      activation_9[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_c (BatchNormalization (None, 63, 63, 512)  2048        res_3_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_copy (BatchNormalizat (None, 63, 63, 512)  2048        res_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 63, 63, 512)  0           bn_3_conv_c[0][0]
#                                                                  bn_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 63, 63, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_a (Conv2D)     (None, 63, 63, 128)  65664       activation_12[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_a (BatchNormali (None, 63, 63, 128)  512         res_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 63, 63, 128)  0           bn_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_b (Conv2D)     (None, 63, 63, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_b (BatchNormali (None, 63, 63, 128)  512         res_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 63, 63, 128)  0           bn_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_c (Conv2D)     (None, 63, 63, 512)  66048       activation_14[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_c (BatchNormali (None, 63, 63, 512)  2048        res_3_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 63, 63, 512)  0           bn_3_identity_1_c[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 63, 63, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_a (Conv2D)     (None, 63, 63, 128)  65664       activation_15[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_a (BatchNormali (None, 63, 63, 128)  512         res_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 63, 63, 128)  0           bn_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_b (Conv2D)     (None, 63, 63, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_b (BatchNormali (None, 63, 63, 128)  512         res_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 63, 63, 128)  0           bn_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_c (Conv2D)     (None, 63, 63, 512)  66048       activation_17[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_c (BatchNormali (None, 63, 63, 512)  2048        res_3_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 63, 63, 512)  0           bn_3_identity_2_c[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 63, 63, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res_4_conv_a (Conv2D)           (None, 63, 63, 256)  131328      activation_18[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_a (BatchNormalization (None, 63, 63, 256)  1024        res_4_conv_a[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 63, 63, 256)  0           bn_4_conv_a[0][0]
# __________________________________________________________________________________________________
# res_4_conv_b (Conv2D)           (None, 63, 63, 256)  590080      activation_19[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_b (BatchNormalization (None, 63, 63, 256)  1024        res_4_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 63, 63, 256)  0           bn_4_conv_b[0][0]
# __________________________________________________________________________________________________
# res_4_conv_c (Conv2D)           (None, 63, 63, 1024) 263168      activation_20[0][0]
# __________________________________________________________________________________________________
# res_4_conv_copy (Conv2D)        (None, 63, 63, 1024) 525312      activation_18[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_c (BatchNormalization (None, 63, 63, 1024) 4096        res_4_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_copy (BatchNormalizat (None, 63, 63, 1024) 4096        res_4_conv_copy[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 63, 63, 1024) 0           bn_4_conv_c[0][0]
#                                                                  bn_4_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 63, 63, 1024) 0           add_6[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_a (Conv2D)     (None, 63, 63, 256)  262400      activation_21[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_a (BatchNormali (None, 63, 63, 256)  1024        res_4_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 63, 63, 256)  0           bn_4_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_b (Conv2D)     (None, 63, 63, 256)  590080      activation_22[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_b (BatchNormali (None, 63, 63, 256)  1024        res_4_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 63, 63, 256)  0           bn_4_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_c (Conv2D)     (None, 63, 63, 1024) 263168      activation_23[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_c (BatchNormali (None, 63, 63, 1024) 4096        res_4_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 63, 63, 1024) 0           bn_4_identity_1_c[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 63, 63, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_a (Conv2D)     (None, 63, 63, 256)  262400      activation_24[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_a (BatchNormali (None, 63, 63, 256)  1024        res_4_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 63, 63, 256)  0           bn_4_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_b (Conv2D)     (None, 63, 63, 256)  590080      activation_25[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_b (BatchNormali (None, 63, 63, 256)  1024        res_4_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 63, 63, 256)  0           bn_4_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_c (Conv2D)     (None, 63, 63, 1024) 263168      activation_26[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_c (BatchNormali (None, 63, 63, 1024) 4096        res_4_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 63, 63, 1024) 0           bn_4_identity_2_c[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 63, 63, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res_5_conv_a (Conv2D)           (None, 63, 63, 512)  524800      activation_27[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_a (BatchNormalization (None, 63, 63, 512)  2048        res_5_conv_a[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 63, 63, 512)  0           bn_5_conv_a[0][0]
# __________________________________________________________________________________________________
# res_5_conv_b (Conv2D)           (None, 63, 63, 512)  2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_b (BatchNormalization (None, 63, 63, 512)  2048        res_5_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 63, 63, 512)  0           bn_5_conv_b[0][0]
# __________________________________________________________________________________________________
# res_5_conv_c (Conv2D)           (None, 63, 63, 2048) 1050624     activation_29[0][0]
# __________________________________________________________________________________________________
# res_5_conv_copy (Conv2D)        (None, 63, 63, 2048) 2099200     activation_27[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_c (BatchNormalization (None, 63, 63, 2048) 8192        res_5_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_copy (BatchNormalizat (None, 63, 63, 2048) 8192        res_5_conv_copy[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 63, 63, 2048) 0           bn_5_conv_c[0][0]
#                                                                  bn_5_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 63, 63, 2048) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_a (Conv2D)     (None, 63, 63, 512)  1049088     activation_30[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_a (BatchNormali (None, 63, 63, 512)  2048        res_5_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 63, 63, 512)  0           bn_5_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_b (Conv2D)     (None, 63, 63, 512)  2359808     activation_31[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_b (BatchNormali (None, 63, 63, 512)  2048        res_5_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 63, 63, 512)  0           bn_5_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_c (Conv2D)     (None, 63, 63, 2048) 1050624     activation_32[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_c (BatchNormali (None, 63, 63, 2048) 8192        res_5_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 63, 63, 2048) 0           bn_5_identity_1_c[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 63, 63, 2048) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_a (Conv2D)     (None, 63, 63, 512)  1049088     activation_33[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_a (BatchNormali (None, 63, 63, 512)  2048        res_5_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 63, 63, 512)  0           bn_5_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_b (Conv2D)     (None, 63, 63, 512)  2359808     activation_34[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_b (BatchNormali (None, 63, 63, 512)  2048        res_5_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 63, 63, 512)  0           bn_5_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_c (Conv2D)     (None, 63, 63, 2048) 1050624     activation_35[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_c (BatchNormali (None, 63, 63, 2048) 8192        res_5_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 63, 63, 2048) 0           bn_5_identity_2_c[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 63, 63, 2048) 0           add_11[0][0]
# __________________________________________________________________________________________________
# Averagea_Pooling (AveragePoolin (None, 31, 31, 2048) 0           activation_36[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1968128)      0           Averagea_Pooling[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1968128)      0           flatten[0][0]
# __________________________________________________________________________________________________
# Dense_final (Dense)             (None, 2)            3936258     dropout[0][0]
# ==================================================================================================
# Total params: 23,876,226
# Trainable params: 23,833,858
# Non-trainable params: 42,368
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = RMSprop(lr=0.0001), 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['accuracy'])
history = model.fit(
            train_generator,
            validation_data = validation_generator,
            epochs = 1,
            verbose = 1)

# %%
# assign label names to the corresponding indexes
labels = {1:"PNEUMONIA",0:"NORMAL"}

# %%
# load images and their predictions 

import cv2
labels = {0:'NORMAL', 1:'PNEUMONIA'}
DIR = "data/test" 
prediction = []
original = []
image = []
count = 0
for i in ["PNEUMONIA","NORMAL"]:
    count = 0
    
    for item in os.listdir(os.path.join(DIR, i)):
        #store only three images
        if count==3:
            break
        img= cv2.imread(os.path.join(DIR, i, item))
        # resizing the image to (256,256)
        img = cv2.resize(img,(256, 256))
        image.append(img)
        # converting image to array
        img = np.asarray(img, dtype = np.float32)
        img = img / 255
        img = img.reshape(-1, 256, 256, 3)
        # making prediction of the model
        predict = model.predict(img)
        predict = np.argmax(predict)
        prediction.append(labels[predict])
        original.append(i)
        count+=1

# %%
# visualize the results
import random
fig = plt.figure(figsize = (50,50))
for i in range(6):
    j = random.randint(0, len(image))
    fig.add_subplot(20, 1, i+1)
    plt.xlabel("Prediction: " + prediction[j] +"   Original: " + original[j])
    plt.imshow(image[j])
fig.tight_layout()
plt.show()

# %% [markdown]
# #VISUALIZING ACTIVATION MAPS THROUGH GRAD-CAM

# %%
def grad_cam(img):
    
    

    # Convert the image to array of type float32
    img = np.asarray(img, dtype = np.float32)

    # Reshape the image from (256,256,3) to (1,256,256,3)
    img = img.reshape(-1, 256, 256, 3)
    img_scaled = img / 255

    # Name of the average pooling layer and dense final (you can see these names in the model summary)
    classification_layers = ["Averagea_Pooling", "Dense_final"]

    # Last convolutional layer in the model
    final_conv = model.get_layer("res_5_identity_2_c")

    # Create a model with original model inputs and the last conv_layer as the output
    final_conv_model = keras.Model(model.inputs, final_conv.output)

    
    #  the conv layer is of the shape (1,3,3,2048) 
    classification_input = keras.Input(shape = final_conv.output.shape[1:])
#     print(final_conv.output.shape[1:])

    # We iterate through the classification layers, to get the final layer and then append 
    # the layer as the output layer to the classification model.
    temp = classification_input
    for layer in classification_layers:
        temp = model.get_layer(layer)(temp)
    classification_model = keras.Model(classification_input, temp)


    # We use gradient tape to monitor the 'final_conv_output' to retrive the gradients
    # corresponding to the predicted class
    with tf.GradientTape() as tape:
        final_conv_output = final_conv_model(img_scaled)
        tape.watch(final_conv_output)

    prediction = classification_model(final_conv_output)
    if prediction > 0.5:
        prediction = 
    predicted_class = tf.argmax(prediction[0][0][0])
    predicted_class_value = prediction[:,:,:,predicted_class]

    # Get the gradient corresponding to the predicted class based on feature map.
    # which is of shape (1,3,3,2048)
    gradient = tape.gradient(predicted_class_value, final_conv_output)

    # Since we need the filter values (2048), we reduce the other dimensions, 
    # which would result in a shape of (2048,)
    gradient_channels = tf.reduce_mean(gradient, axis=(0, 1, 2))

    # We then convert the feature map produced by last conv layer(1,6,6,1536) to (6,6,1536)
    final_conv_output = final_conv_output.numpy()[0]

    gradient_channels = gradient_channels.numpy()

    # We multiply the filters in the feature map produced by final conv layer by the 
    # filter values that are used to get the predicted class. By doing this we inrease the
    # value of areas that helped in making the prediction and lower the vlaue of areas, that 
    # did not contribute towards the final prediction
    for i in range(gradient_channels.shape[-1]):
        final_conv_output[:, :, i] *= gradient_channels[i]

    # We take the mean accross the channels to get the feature map
    heatmap = np.mean(final_conv_output, axis=-1)

    # Normalizing the heat map between 0 and 1, to visualize it
    heatmap_normalized = np.maximum(heatmap, 0) / np.max(heatmap)

    # Rescaling and converting the type to int
    heatmap = np.uint8(255 * heatmap_normalized )

    # Create the colormap
    color_map = plt.cm.get_cmap('jet')

    # get only the rb features from the heatmap
    color_map = color_map(np.arange(256))[:, :3]
    heatmap = color_map[heatmap]

    # convert the array to image, resize the image and then convert to array
    heatmap = keras.preprocessing.image.array_to_img(heatmap)
    heatmap = heatmap.resize((256, 256))
    heatmap = np.asarray(heatmap, dtype = np.float32)

    # Add the heatmap on top of the original image
    final_img = heatmap * 0.4 + img[0]
    final_img = keras.preprocessing.image.array_to_img(final_img)

    return final_img, heatmap_normalized

# %%
# Visualize the images in the dataset
import random
fig, axs = plt.subplots(6,3, figsize = (16,32))
count = 0
for _ in range(6):
    i = random.randint(0, len(image))
    gradcam, heatmap = grad_cam(image[i])
    axs[count][0].title.set_text("Original -" + original[i])
    axs[count][0].imshow(image[i])
    axs[count][1].title.set_text("Heatmap") 
    axs[count][1].imshow(heatmap)
    axs[count][2].title.set_text("Prediction -" + prediction[i]) 
    axs[count][2].imshow(gradcam)  
    count += 1

fig.tight_layout()
